# %% [markdown]
# # 1. Data Scraping

# %% [markdown]
# The scrape code was created using the tutorial available on the webpage:
# https://simpleanalytical.com/how-to-web-scrape-wikipedia-python-urllib-beautiful-soup-pandas
#
# By: Alan Hylands

# %%
import urllib.request

# %% [markdown]
# Downloading the page

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)

# %% [markdown]
# Extracting the date from the page

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page, "lxml")

# %%
all_tables=soup.find_all("table")

# %%
right_table=soup.find('table', class_='wikitable')

# %%
A=[]
B=[]
C=[]

for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        if cells[1].find(text=True)[:-1]!="Not assigned":
            #The strings have a '\n' at their end
            # that is why I will remove the lat letter
            A.append(cells[0].find(text=True)[:-1])
            B.append(cells[1].find(text=True)[:-1])
            #Some zip codes have multiple neighbourhoods
            # that is why I will take only the first one of them
            C.append(cells[2].find(text=True)[:-1].partition('/')[0])

# %% [markdown]
# Putting the data in a DataFrame

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Zip'])
df['Borough']=B
df['Neighborhood']=C
df
# Out:
#      Zip           Borough                           Neighborhood
# 0    M3A        North York                              Parkwoods
# 1    M4A        North York                       Victoria Village
# 2    M5A  Downtown Toronto                           Regent Park
# 3    M6A        North York                        Lawrence Manor
# 4    M7A  Downtown Toronto                          Queen's Park
# 5    M9A         Etobicoke                       Islington Avenue
# 6    M1B       Scarborough                               Malvern
# 7    M3B        North York                              Don Mills
# 8    M4B         East York                         Parkview Hill
# 9    M5B  Downtown Toronto               Garden District, Ryerson
# 10   M6B        North York                              Glencairn
# 11   M9B         Etobicoke                       West Deane Park
# 12   M1C       Scarborough                            Rouge Hill
# 13   M3C        North York                              Don Mills
# 14   M4C         East York                       Woodbine Heights
# 15   M5C  Downtown Toronto                         St. James Town
# 16   M6C              York                     Humewood-Cedarvale
# 17   M9C         Etobicoke                              Eringate
# 18   M1E       Scarborough                             Guildwood
# 19   M4E      East Toronto                            The Beaches
# 20   M5E  Downtown Toronto                            Berczy Park
# 21   M6E              York                    Caledonia-Fairbanks
# 22   M1G       Scarborough                                 Woburn
# 23   M4G         East York                                Leaside
# 24   M5G  Downtown Toronto                     Central Bay Street
# 25   M6G  Downtown Toronto                               Christie
# 26   M1H       Scarborough                              Cedarbrae
# 27   M2H        North York                      Hillcrest Village
# 28   M3H        North York                        Bathurst Manor
# 29   M4H         East York                       Thorncliffe Park
# 30   M5H  Downtown Toronto                              Richmond
# 31   M6H      West Toronto                              Dufferin
# 32   M1J       Scarborough                    Scarborough Village
# 33   M2J        North York                              Fairview
# 34   M3J        North York                        Northwood Park
# 35   M4J         East York                           East Toronto
# 36   M5J  Downtown Toronto                     Harbourfront East
# 37   M6J      West Toronto                       Little Portugal
# 38   M1K       Scarborough                          Kennedy Park
# 39   M2K        North York                        Bayview Village
# 40   M3K        North York                              Downsview
# 41   M4K      East Toronto                     The Danforth West
# 42   M5K  Downtown Toronto               Toronto Dominion Centre
# 43   M6K      West Toronto                              Brockton
# 44   M1L       Scarborough                           Golden Mile
# 45   M2L        North York                            York Mills
# 46   M3L        North York                              Downsview
# 47   M4L      East Toronto                          India Bazaar
# 48   M5L  Downtown Toronto                        Commerce Court
# 49   M6L        North York                            North Park
# 50   M9L        North York                          Humber Summit
# 51   M1M       Scarborough                             Cliffside
# 52   M2M        North York                            Willowdale
# 53   M3M        North York                              Downsview
# 54   M4M      East Toronto                        Studio District
# 55   M5M        North York                          Bedford Park
# 56   M6M              York                               Del Ray
# 57   M9M        North York                             Humberlea
# 58   M1N       Scarborough                           Birch Cliff
# 59   M2N        North York                             Willowdale
# 60   M3N        North York                              Downsview
# 61   M4N   Central Toronto                          Lawrence Park
# 62   M5N   Central Toronto                               Roselawn
# 63   M6N              York                             Runnymede
# 64   M9N              York                                 Weston
# 65   M1P       Scarborough                           Dorset Park
# 66   M2P        North York                        York Mills West
# 67   M4P   Central Toronto                       Davisville North
# 68   M5P   Central Toronto               Forest Hill North & West
# 69   M6P      West Toronto                             High Park
# 70   M9P         Etobicoke                              Westmount
# 71   M1R       Scarborough                               Wexford
# 72   M2R        North York                             Willowdale
# 73   M4R   Central Toronto                     North Toronto West
# 74   M5R   Central Toronto                             The Annex
# 75   M6R      West Toronto                              Parkdale
# 76   M7R       Mississauga  Canada Post Gateway Processing Centre
# 77   M9R         Etobicoke                     Kingsview Village
# 78   M1S       Scarborough                              Agincourt
# 79   M4S   Central Toronto                             Davisville
# 80   M5S  Downtown Toronto                 University of Toronto
# 81   M6S      West Toronto                             Runnymede
# 82   M1T       Scarborough                        Clarks Corners
# 83   M4T   Central Toronto                            Moore Park
# 84   M5T  Downtown Toronto                     Kensington Market
# 85   M1V       Scarborough                              Milliken
# 86   M4V   Central Toronto                       Summerhill West
# 87   M5V  Downtown Toronto                              CN Tower
# 88   M8V         Etobicoke                           New Toronto
# 89   M9V         Etobicoke                         South Steeles
# 90   M1W       Scarborough                          Steeles West
# 91   M4W  Downtown Toronto                               Rosedale
# 92   M5W  Downtown Toronto                         Stn A PO Boxes
# 93   M8W         Etobicoke                             Alderwood
# 94   M9W         Etobicoke                              Northwest
# 95   M1X       Scarborough                            Upper Rouge
# 96   M4X  Downtown Toronto                        St. James Town
# 97   M5X  Downtown Toronto                  First Canadian Place
# 98   M8X         Etobicoke                          The Kingsway
# 99   M4Y  Downtown Toronto                   Church and Wellesley
# 100  M7Y      East Toronto  Business reply mail Processing CentrE
# 101  M8Y         Etobicoke                        Old Mill South
# 102  M8Z         Etobicoke                             Mimico NW

# %% [markdown]
# # 2. Downloading the Data of Neighborhoods and Venues

# %% [markdown]
# Importing the necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Getting the Coordinates of the different Neighborhoods

# %%
AA=[]
geolocator = Nominatim(user_agent="foursquare_agent")
for ii,cc in enumerate(np.array(df)):
    address=cc[2]+', '+cc[1]+', Canada'
    location = geolocator.geocode(address)
    if location: #Some locations have no data
        latitude = location.latitude
        longitude = location.longitude
        #Saving all the data of the locations in an array
        AA.append([cc[0],cc[1],cc[2], latitude, longitude])

# %%
print(ii)
# Out:
# 102

# %%
#Turning the array into a DataFrame
df2=pd.DataFrame(AA)
df2=df2.rename(columns={0: "Zip", 1: "Borough" , 2: "Neighborhood" , 3: "Latitude" , 4: "Longitude"})

df2
# Out:
#     Zip           Borough              Neighborhood   Latitude  Longitude
# 0   M3A        North York                 Parkwoods  43.758800 -79.320197
# 1   M4A        North York          Victoria Village  43.732658 -79.311189
# 2   M6A        North York           Lawrence Manor   43.722079 -79.437507
# 3   M7A  Downtown Toronto             Queen's Park   43.663217 -79.386290
# 4   M9A         Etobicoke          Islington Avenue  43.622575 -79.514215
# 5   M1B       Scarborough                  Malvern   43.809196 -79.221701
# 6   M3B        North York                 Don Mills  43.775347 -79.345944
# 7   M6B        North York                 Glencairn  43.708712 -79.440685
# 8   M9B         Etobicoke          West Deane Park   43.663199 -79.568568
# 9   M1C       Scarborough               Rouge Hill   43.780271 -79.130499
# 10  M3C        North York                 Don Mills  43.775347 -79.345944
# 11  M4C         East York          Woodbine Heights  43.699930 -79.319132
# 12  M9C         Etobicoke                 Eringate   43.662273 -79.576516
# 13  M1E       Scarborough                Guildwood   43.755225 -79.198229
# 14  M4E      East Toronto               The Beaches  43.671024 -79.296712
# 15  M1G       Scarborough                    Woburn  43.759824 -79.225291
# 16  M4G         East York                   Leaside  43.704798 -79.368090
# 17  M5G  Downtown Toronto        Central Bay Street  43.661425 -79.386067
# 18  M6G  Downtown Toronto                  Christie  43.649991 -79.385722
# 19  M1H       Scarborough                 Cedarbrae  43.756467 -79.226692
# 20  M2H        North York         Hillcrest Village  43.799664 -79.365019
# 21  M3H        North York           Bathurst Manor   43.724975 -79.431073
# 22  M4H         East York          Thorncliffe Park  43.704553 -79.345407
# 23  M5H  Downtown Toronto                 Richmond   43.652477 -79.380628
# 24  M6H      West Toronto                 Dufferin   43.660202 -79.435719
# 25  M1J       Scarborough       Scarborough Village  43.743742 -79.211632
# 26  M2J        North York                 Fairview   43.754326 -79.449117
# 27  M3J        North York           Northwood Park   43.754135 -79.504480
# 28  M4J         East York              East Toronto  43.670862 -79.372792
# 29  M6J      West Toronto          Little Portugal   43.647413 -79.431116
# 30  M1K       Scarborough             Kennedy Park   43.724878 -79.253969
# 31  M2K        North York           Bayview Village  43.769197 -79.376662
# 32  M3K        North York                 Downsview  43.749299 -79.462248
# 33  M4K      East Toronto        The Danforth West   43.687017 -79.297511
# 34  M6K      West Toronto                 Brockton   43.650917 -79.440022
# 35  M1L       Scarborough              Golden Mile   43.727841 -79.287622
# 36  M2L        North York               York Mills   43.744039 -79.406657
# 37  M3L        North York                 Downsview  43.749299 -79.462248
# 38  M6L        North York               North Park   43.718690 -79.477534
# 39  M9L        North York             Humber Summit  43.760078 -79.571760
# 40  M1M       Scarborough                Cliffside   43.711170 -79.248177
# 41  M2M        North York               Willowdale   43.761510 -79.410923
# 42  M3M        North York                 Downsview  43.749299 -79.462248
# 43  M4M      East Toronto           Studio District  43.649585 -79.390683
# 44  M5M        North York             Bedford Park   43.737388 -79.410925
# 45  M9M        North York                Humberlea   43.721317 -79.533160
# 46  M1N       Scarborough              Birch Cliff   43.702112 -79.260091
# 47  M2N        North York                Willowdale  43.761510 -79.410923
# 48  M3N        North York                 Downsview  43.749299 -79.462248
# 49  M4N   Central Toronto             Lawrence Park  43.729199 -79.403252
# 50  M5N   Central Toronto                  Roselawn  43.699456 -79.454616
# 51  M6N              York                Runnymede   43.665580 -79.482108
# 52  M9N              York                    Weston  43.700161 -79.516247
# 53  M1P       Scarborough              Dorset Park   43.752847 -79.282067
# 54  M2P        North York           York Mills West  43.744039 -79.406657
# 55  M4P   Central Toronto          Davisville North  43.697936 -79.397291
# 56  M5P   Central Toronto  Forest Hill North & West  43.701028 -79.425600
# 57  M6P      West Toronto                High Park   43.653867 -79.466864
# 58  M9P         Etobicoke                 Westmount  43.693640 -79.521043
# 59  M1R       Scarborough                  Wexford   43.745377 -79.294715
# 60  M2R        North York                Willowdale  43.761510 -79.410923
# 61  M5R   Central Toronto                The Annex   43.670338 -79.407117
# 62  M6R      West Toronto                 Parkdale   43.640495 -79.436897
# 63  M9R         Etobicoke        Kingsview Village   43.699539 -79.556346
# 64  M1S       Scarborough                 Agincourt  43.785353 -79.278549
# 65  M4S   Central Toronto                Davisville  43.697936 -79.397291
# 66  M6S      West Toronto                Runnymede   43.651703 -79.475998
# 67  M1T       Scarborough           Clarks Corners   43.796410 -79.297795
# 68  M4T   Central Toronto               Moore Park   43.690388 -79.383297
# 69  M1V       Scarborough                 Milliken   43.823174 -79.301763
# 70  M4V   Central Toronto          Summerhill West   43.681678 -79.390504
# 71  M8V         Etobicoke              New Toronto   43.600763 -79.505264
# 72  M9V         Etobicoke            South Steeles   43.759270 -79.596835
# 73  M1W       Scarborough             Steeles West   43.816178 -79.314538
# 74  M4W  Downtown Toronto                  Rosedale  43.656322 -79.380916
# 75  M8W         Etobicoke                Alderwood   43.601717 -79.545232
# 76  M9W         Etobicoke                 Northwest  43.671459 -79.552492
# 77  M1X       Scarborough               Upper Rouge  43.804930 -79.165837
# 78  M8X         Etobicoke             The Kingsway   43.647381 -79.511333
# 79  M4Y  Downtown Toronto      Church and Wellesley  43.661195 -79.382114
# 80  M8Y         Etobicoke           Old Mill South   43.649826 -79.494334
# 81  M8Z         Etobicoke                Mimico NW   43.616677 -79.496805

# %% [markdown]
# ### Obtaining the coordinates of Toronto

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="TO_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### Visualizing the locations of the Neighborhoods on the map of Toronto

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, label in zip(df2[3], df2[4], df2[2]):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
